# %%
import pandas as pd

# %%
original = pd.read_csv('219229352_T_ONTIME_REPORTING.csv')

# %%
original.head(5)
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0  2021        1      1             5            2  2021-01-05
# 1  2021        1      1             5            2  2021-01-05
# 2  2021        1      1             5            2  2021-01-05
# 3  2021        1      1             5            2  2021-01-05
# 4  2021        1      1             5            2  2021-01-05
#
#   OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ...  \
# 0                OO   N263SY               3695              14831  ...
# 1                OO   N831SK               3696              14683  ...
# 2                OO   N304SY               3698              14771  ...
# 3                OO   N280SY               3700              12892  ...
# 4                OO   N240SY               3701              13851  ...
#
#        DEST_CITY_NAME  DEST_STATE_ABR DEST_STATE_NM DEST_WAC DEP_TIME  \
# 0  Salt Lake City, UT              UT          Utah       87   1704.0
# ...

# %%
original.describe()
# Out:
#            YEAR   QUARTER     MONTH   DAY_OF_MONTH    DAY_OF_WEEK  \
# count  361428.0  361428.0  361428.0  361428.000000  361428.000000
# mean     2021.0       1.0       1.0      15.694288       4.248630
# std         0.0       0.0       0.0       9.079230       2.032472
# min      2021.0       1.0       1.0       1.000000       1.000000
# 25%      2021.0       1.0       1.0       8.000000       2.000000
# 50%      2021.0       1.0       1.0      16.000000       4.000000
# 75%      2021.0       1.0       1.0      24.000000       6.000000
# max      2021.0       1.0       1.0      31.000000       7.000000
#
#        OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# count      361428.000000      361428.000000           3.614280e+05
# mean         2783.941524       12641.752548           1.264179e+06
# std          1810.245625        1555.995551           1.555992e+05
# min             1.000000       10135.000000           1.013506e+06
# ...

# %%
original.shape
# Out:
# (361428, 31)

# %%
original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361428 entries, 0 to 361427
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   YEAR                     361428 non-null  int64
#  1   QUARTER                  361428 non-null  int64
#  2   MONTH                    361428 non-null  int64
#  3   DAY_OF_MONTH             361428 non-null  int64
#  4   DAY_OF_WEEK              361428 non-null  int64
#  5   FL_DATE                  361428 non-null  object
#  6   OP_UNIQUE_CARRIER        361428 non-null  object
#  7   TAIL_NUM                 360907 non-null  object
#  8   OP_CARRIER_FL_NUM        361428 non-null  int64
#  9   ORIGIN_AIRPORT_ID        361428 non-null  int64
#  10  ORIGIN_AIRPORT_SEQ_ID    361428 non-null  int64
#  11  ORIGIN_CITY_MARKET_ID    361428 non-null  int64
#  12  ORIGIN                   361428 non-null  object
# ...
